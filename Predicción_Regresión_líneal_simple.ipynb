# %%
# Importar librerias
import seaborn as sns
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
# Cargar datos
df = pd.read_excel("datos-producción.xlsx")
df.head(2)
# Out:
#    Nºmuestra  Nueva materia prima (%)  Producto no conforme
# 0          1                      1.0                    10
# 1          2                      2.0                     5

# %%
# Seleccionar variables
variable_x = "Nueva materia prima (%)"
variable_y = "Producto no conforme"

# %%
# Generar análisis
modelo = LinearRegression()
modelo.fit(df[[variable_x]], df[variable_y])
print ('Ecuación de la recta: y = ', round(modelo.coef_[0],3),'x + ', round(modelo.intercept_,3))#obtenemos la ecuación de la recta
print ('Coeficiente de correlación: ', round(np.corrcoef(df[variable_x], df[variable_y])[0,1], 3))#obtenemos el coeficiente de correlación
print ('Coeficiente de determinación: ', round(r2_score(df[variable_y], modelo.predict(df[[variable_x]])), 3))#obtenemos el coeficiente de determinación
# Gráfica con intervalo de confianza
sns.regplot(x=df[variable_x], y=df[variable_y], ci=95, line_kws={"color": "red"}, scatter_kws={"color": "black"})
plt.title('Regresión lineal simple con intervalo de confianza al 95%')
plt.show()
# Out:
# Ecuación de la recta: y =  -2.73 x +  12.532
# Coeficiente de correlación:  -0.888
# Coeficiente de determinación:  0.789

# %%
# Generar PREDICCIÓN
dato_predictor = 1

producto_no_conforme = pd.DataFrame([dato_predictor], columns=[variable_x])  # Convertir a DataFrame
autos_producidos_prediccion = modelo.predict(producto_no_conforme)
print('La predicción de producto no conforme producidos será', producto_no_conforme.iloc[0][0], 'horas trabajadas es', round(autos_producidos_prediccion[0], 3))
# Out:
# La predicción de autos producidos para 1 horas trabajadas es 9.802
